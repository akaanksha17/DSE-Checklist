# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
d=pd.read_csv('insurance.csv')
d
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
d.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.barplot(x='age',y='charges',data=d)

# %%
sns.barplot(x='sex',y='charges',data=d)

# %%
sns.barplot(x='region',y='charges',data=d)

# %%
sns.barplot(x='smoker',y='age',data=d)

# %%
sns.barplot(x='children',y='charges',data=d)

# %%
sns.barplot(x='sex',y='charges',hue='children',data=d)

# %%
sns.distplot(d['age'])

# %%
df=pd.read_csv('book1.csv')
df
# Out:
#       stn_code sampling_date      state   location  \
# 0         77.0      11-02-88  Karnataka  Bangalore
# 1         78.0      11-03-88  Karnataka  Bangalore
# 2         79.0      11-02-88  Karnataka  Bangalore
# 3         80.0      11-03-88  Karnataka  Bangalore
# 4         81.0      11-02-88  Karnataka  Bangalore
# 5         77.0      12-08-88  Karnataka  Bangalore
# 6         78.0      12-01-88  Karnataka  Bangalore
# 7         79.0      12-02-88  Karnataka  Bangalore
# 8         80.0      12-01-88  Karnataka  Bangalore
# 9         81.0      12-02-88  Karnataka  Bangalore
# 10        77.0       M011989  Karnataka  Bangalore
# 11        78.0       M011989  Karnataka  Bangalore
# 12        79.0       M011989  Karnataka  Bangalore
# 13        80.0       M011989  Karnataka  Bangalore
# 14        81.0       M011989  Karnataka  Bangalore
# 15        77.0       M021989  Karnataka  Bangalore
# 16        78.0       M021989  Karnataka  Bangalore
# ...

# %%
sns.lineplot(x='type',y='so2',data=df)

# %%
sns.barplot(x='so2',y='type',data=df)

# %%
sns.relplot(x='so2',y='type',data=df)
