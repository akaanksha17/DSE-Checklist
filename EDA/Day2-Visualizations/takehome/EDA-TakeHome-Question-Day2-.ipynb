# %% [markdown]
# ## UNIVARIATE STATISTICS ANALYSIS

# %% [markdown]
# ## 1. Quantitative:
#
# 1. Kernel Density plot
# 2. Histogram
# 3. Box plot

# %% [markdown]
# ### 1.1Explain about above 3 charts using iris data

# %% [markdown]
# #### 1.1a) Kernel Density plot:

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
# density plot with shade
setosa = df.loc[df.species == "setosa"]
virginica = df.loc[df.species == "virginica"]
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                  cmap="Reds", shade=True,shade_lowest=False)
ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                cmap="Blues", shade=True,shade_lowest=False)

# %% [markdown]
# #### Observations:

# %% [markdown]
# #### 1.1 b) Histogram

# %%
# Import library and dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
# Make default histogram of sepal length
df['sepal_length'].plot.hist()
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# ### 1.1c) Box plot

# %%
 # library & dataset

# Make boxplot for one group only


sns.boxplot(df['sepal_length'])
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# ## 2. Categorical:
#
# 1. Bar chart
# 2. Pie chart

# %% [markdown]
# #### 2.1 Explain about above 2 charts and create new data?

# %% [markdown]
# #### 2.1a) Bar chart

# %%
# Make a fake dataset:
# Create bars
# Create names on the x-axis
# Show graphic

df1=df
fig,ax=plt.subplots(2,2,figsize=(30,10))
print(sns.countplot(df1["petal_length"],ax=ax[0,0])) 
print(sns.countplot(df1["petal_width"],ax=ax[0,1]))
print(sns.countplot(df1["sepal_length"],ax=ax[1,0]))
print(sns.countplot(df1["sepal_width"],ax=ax[1,1])) 
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.352273x0.343182)
# AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# AxesSubplot(0.125,0.125;0.352273x0.343182)
# AxesSubplot(0.547727,0.125;0.352273x0.343182)

# %% [markdown]
# #### Observations:

# %% [markdown]
# # Case study 1

# %% [markdown]
# ### About the Data set (Wine Quality.csv)
# Attribute Information:
#
# The dataset are related to red and white variants of the "Vinho Verde" wine. Vinho verde is a unique product from the Minho (northwest) region of Portugal. Medium in alcohol, is it particularly appreciated due to its freshness (specially in the summer).
#
#     1 - fixed acidity
#     2 - volatile acidity
#     3 - citric acid
#     4 - residual sugar
#     5 - chlorides
#     6 - free sulfur dioxide
#     7 - total sulfur dioxide
#     8 - density
#     9 - pH
#     10 - sulphates
#     11 - alcohol Output variable (based on sensory data):
#     12 - quality (score between 0 and 10)

# %% [markdown]
# ### 1.1 Loading the libraries

# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2 import the  data?

# %%
w=pd.read_csv('Wine_data.csv')
w
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %% [markdown]
# ### 1.3 check the size of your data?

# %%
w.size
# Out:
# 58776

# %% [markdown]
# ### 1.4 How to view the statistical characteristics of the data?

# %%
w.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ### 1.5 Find the how many Numerical Features,Categorical Features, Alphanumeric Features?

# %%
## Categorical: 
print(pd.Categorical(w) )   

##  * Numerical Features: 

num_cols1 = list(w.select_dtypes(exclude=['object']).columns)
print('Numerical Features = ',num_cols1)
# Out:
# [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, ..., density, pH, sulphates, alcohol, quality]
# Length: 12
# Categories (12, object): [alcohol, chlorides, citric acid, density, ..., residual sugar, sulphates, total sulfur dioxide, volatile acidity]
# Numerical Features =  ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# ## 1.6 Univariate Analysis for Quantitative

# %% [markdown]
# ## Kernel Density plot

# %% [markdown]
#     * A density plot shows the distribution of a numerical variable. It takes only set of numeric values as input. It is really close to a histogram. Since it is a really common dataviz technique,

# %% [markdown]
# ### 1.6a) Plot the Kernel Density plot . And your Observations?

# %%
w.plot.kde()

# %% [markdown]
# #### Observations:

# %% [markdown]
# #### 1.6b) Create a box plot for(quality,fixed acidity,volatile acidity,citric acid,free sulfur dioxide,sulphates,density). And your Overall Observations?

# %%
# create box plot for quality.
sns.boxplot(w['quality'])

# %%
# create box plot for fixed acidity.
sns.boxplot(w['fixed acidity'])

# %%
# create box plot for volatile acidity

sns.boxplot(w['volatile acidity'])

# %%
# create box plot for citric acid

sns.boxplot(w['citric acid'])

# %%
# create box plot for free sulfur dioxide

sns.boxplot(w['free sulfur dioxide'])

# %%
# create box plot for sulphates

sns.boxplot(w['sulphates'])

# %%
# create box plot for density
sns.boxplot(w['density'])

# %% [markdown]
# #### Over all Observations:

# %% [markdown]
# ### 1.6c)quality Analysis using bar chart and Pie chart. and your Overall Observations?

# %%
# plot a Bar plot

w['quality'].value_counts(normalize=True).plot.bar()
plt.show()

# %% [markdown]
# #### Observations:

# %%
# plot a pie and bar plot using subplots(1,2,figsize=(8,5))
fig,ax=plt.subplots(1,2,figsize=(8,5))
w['quality'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0])
ax[0].set_title('quality')
sns.countplot('quality',data=w,ax=ax[1])
ax[1].set_title('quality analysis')
plt.show()

# %% [markdown]
# Observations:

# %% [markdown]
# ####  1.7 importing import skew, norm

# %%
from scipy.stats import norm,skew
w.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# #### 1.8 Create the numeric_features to remove skewness

# %%
numeric_features=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# #### 1.9 Create the skewed_features = wines[numeric_features]

# %%
skewed_features=w[numeric_features].skew()
skewed_features
# Out:
# fixed acidity           0.647751
# volatile acidity        1.576980
# citric acid             1.281920
# residual sugar          1.077094
# chlorides               5.023331
# free sulfur dioxide     1.406745
# total sulfur dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %% [markdown]
# #### 1.10 Create DataFrame for skewness?

# %%
dataframe=pd.DataFrame([skewed_features])
dataframe
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.647751           1.57698      1.28192        1.077094   5.023331
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             1.406745               0.39071  0.977773  0.457783   0.977194
#
#     alcohol   quality
# 0  0.487342  0.155796

# %% [markdown]
# #### 1.11 Create to Get only higest skewed = [abs(skewness) > 0.7] features?

# %%
# Get only higest skewed features
higest_skewed=skewed_features[(skewed_features)>0.7]
higest_skewed
# Out:
# volatile acidity       1.576980
# citric acid            1.281920
# residual sugar         1.077094
# chlorides              5.023331
# free sulfur dioxide    1.406745
# density                0.977773
# sulphates              0.977194
# dtype: float64

# %% [markdown]
# #### 1.12 Create skewness.index and new skewed_features2

# %%
#Create Empty list 

#create for loop for skewness.index

    
#create skewed_features2 for skewness.index

# %% [markdown]
# #### 1.13 Create new DataFrame for skewed_features2?

# %%
#compute skewness


# concat both skewness, skewness2

# %% [markdown]
# ### 1.14 Compare the box plot skewness reduce or not. And Your Observations?

# %%
# compare boxplot

# %% [markdown]
# #### Observations:

# %% [markdown]
# # THE END
